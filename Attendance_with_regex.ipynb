# %%
import pandas as pd
import re
import numpy as np
import datetime
import datetime
from datetime import time
import dateutil
import pytz

# %%
atn="D:\\FB\\PY\\SAL\\Attendancereg.xlsx"

# %%
atd=pd.DataFrame()

# %%
atd=pd.read_excel(atn)

# %%
atd
# Out:
#      Unnamed: 0 Monthly Status Report (Detailed Work Duration) Unnamed: 2  \
# 0           NaN                   Dec 01 2021  To  Dec 31 2021        NaN
# 1      Company:                                            NaN        NaN
# 2           NaN                                            NaN        NaN
# 3           NaN                                            NaN        NaN
# 4          Days                                            NaN        1 W
# ...         ...                                            ...        ...
# 1044   Duration                                            NaN        NaN
# 1045    Late By                                            NaN        NaN
# 1046   Early By                                            NaN        NaN
# 1047         OT                                            NaN        NaN
# 1048      Shift                                            NaN        NaN
#
#      Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8  \
# ...
